# %%
import tkinter
from tkinter import *
calcu=Tk()
calcu.title('calculator')
calcu.geometry('262x283')
calcu.configure(bg='black')
c1=Label(calcu,text='CALCULATOR',font=('Italic',25),bg='black',fg='white')
c1.place(x=15,y=10)
inpt=StringVar()
e1=Entry(width=43,textvariable=inpt,justify=RIGHT)
e1.place(x=0,y=59)
def click(a):
    global exp
    exp=exp+str(a)
    inpt.set(exp)
def clear():
    global exp
    exp=''
    inpt.set('')
def eql():
    global exp
    res=str(eval(exp))
    inpt.set(res)
exp=''
n1=Button(calcu,text=' ( ',width=7,command=lambda:click('('),bg='black',height=2,fg='white')
n1.place(x=2,y=80)
n2=Button(calcu,text=' ) ',width=7,command=lambda:click(')'),bg='black',height=2,fg='white')
n2.place(x=61,y=80)
n3=Button(calcu,text=' % ',width=7,command=lambda:click('%'),bg='black',height=2,fg='white')
n3.place(x=120,y=80)
n4=Button(calcu,text=' 1 ',width=7,command=lambda:click('1'),bg='black',height=2,fg='white')
n4.place(x=2,y=120)
n5=Button(calcu,text=' 2 ',width=7,command=lambda:click('2'),bg='black',height=2,fg='white')
n5.place(x=61,y=120)
n6=Button(calcu,text=' 3 ',width=7,command=lambda:click('3'),bg='black',height=2,fg='white')
n6.place(x=120,y=120)
n7=Button(calcu,text=' 4 ',width=7,command=lambda:click('4'),bg='black',height=2,fg='white')
n7.place(x=2,y=160)
n8=Button(calcu,text=' 5 ',width=7,command=lambda:click('5'),bg='black',height=2,fg='white')
n8.place(x=61,y=160)
n9=Button(calcu,text=' 6 ',width=7,command=lambda:click('6'),bg='black',height=2,fg='white')
n9.place(x=120,y=160)
n0=Button(calcu,text=' 7 ',width=7,command=lambda:click('7'),bg='black',height=2,fg='white')
n0.place(x=2,y=200)
b1=Button(calcu,text=' + ',command=lambda:click('+'),width=10,bg='navy blue',height=2,fg='white')
b1.place(x=180,y=80)
b2=Button(calcu,text='  -  ',command=lambda:click('-'),width=10,bg='navy blue',height=2,fg='white')
b2.place(x=180,y=120)
b3=Button(calcu,text='  *  ',command=lambda:click('*'),width=10,bg='navy blue',height=2,fg='white')
b3.place(x=180,y=160)
b4=Button(calcu,text='  /  ',command=lambda:click('/'),width=10,bg='navy blue',height=2,fg='white')
b4.place(x=180,y=200)
b5=Button(calcu,text='  c  ',command=clear,width=7,bg='Dark green',height=2,fg='white')
b5.place(x=120,y=239)
b6=Button(calcu,text='  =  ',command=eql,width=10,bg='Dark green',height=2,fg='white')
b6.place(x=180,y=239)
n10=Button(calcu,text=' . ',width=7,command=lambda:click('.'),bg='black',height=2,fg='white')
n10.place(x=2,y=239)
n11=Button(calcu,text=' 0 ',width=7,command=lambda:click('0'),bg='black',height=2,fg='white')
n11.place(x=61,y=239)
n12=Button(calcu,text=' 8 ',width=7,command=lambda:click('8'),bg='black',height=2,fg='white')
n12.place(x=61,y=200)
n13=Button(calcu,text=' 9 ',width=7,command=lambda:click('9'),bg='black',height=2,fg='white')
n13.place(x=120,y=200)
calcu.mainloop()
